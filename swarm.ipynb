# %% [markdown]
# # Variables

# %%
if False:
# LangGraph Swarm
    # %pip install langchain_openai langgraph langgraph-swarm langgraph-supervisor ipykernel
# Out:
# Requirement already satisfied: langchain_openai in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (0.3.18)
# Requirement already satisfied: langgraph in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (0.4.7)
# Requirement already satisfied: langgraph-swarm in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (0.0.11)
# Requirement already satisfied: langgraph-supervisor in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (0.0.25)
# Requirement already satisfied: ipykernel in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (6.29.5)
# Requirement already satisfied: tiktoken<1,>=0.7 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langchain_openai) (0.9.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.61 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langchain_openai) (0.3.61)
# Requirement already satisfied: openai<2.0.0,>=1.68.2 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langchain_openai) (1.82.0)
# Requirement already satisfied: langgraph-sdk>=0.1.42 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langgraph) (0.1.70)
# Requirement already satisfied: langgraph-checkpoint>=2.0.26 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langgraph) (2.0.26)
# Requirement already satisfied: pydantic>=2.7.4 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langgraph) (2.11.5)
# Requirement already satisfied: langgraph-prebuilt>=0.2.0 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langgraph) (0.2.1)
# Requirement already satisfied: xxhash>=3.5.0 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langgraph) (3.5.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: ipython>=7.23.1 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from ipykernel) (8.36.0)
# Requirement already satisfied: psutil in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from ipykernel) (7.0.0)
# Requirement already satisfied: debugpy>=1.6.5 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from ipykernel) (1.8.14)
# Requirement already satisfied: traitlets>=5.4.0 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from ipykernel) (5.7.2)
# Requirement already satisfied: packaging in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from ipykernel) (24.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: pyzmq>=24 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from ipykernel) (26.4.0)
# Requirement already satisfied: comm>=0.1.1 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from ipykernel) (0.2.2)
# Requirement already satisfied: tornado>=6.1 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from ipykernel) (6.5.1)
# Requirement already satisfied: colorama in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: pygments>=2.4.0 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (2.19.1)
# Requirement already satisfied: typing_extensions>=4.6 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (4.13.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.51)
# Requirement already satisfied: decorator in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: stack_data in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: jedi>=0.16 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: exceptiongroup in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (1.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from jupyter-client>=6.1.12->ipykernel) (2.9.0.post0)
# Requirement already satisfied: pywin32>=300 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (310)
# Requirement already satisfied: platformdirs>=2.5 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.126 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.61->langchain_openai) (0.3.42)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.61->langchain_openai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.61->langchain_openai) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.61->langchain_openai) (9.1.2)
# Requirement already satisfied: jsonpointer>=1.9 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.61->langchain_openai) (3.0.0)
# Requirement already satisfied: ormsgpack<2.0.0,>=1.8.0 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langgraph-checkpoint>=2.0.26->langgraph) (1.10.0)
# Requirement already satisfied: orjson>=3.10.1 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langgraph-sdk>=0.1.42->langgraph) (3.10.18)
# Requirement already satisfied: httpx>=0.25.2 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langgraph-sdk>=0.1.42->langgraph) (0.28.1)
# Requirement already satisfied: anyio in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph) (4.9.0)
# Requirement already satisfied: certifi in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph) (1.0.9)
# Requirement already satisfied: idna in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph) (3.10)
# Requirement already satisfied: h11>=0.16 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph) (0.16.0)
# Requirement already satisfied: requests<3,>=2 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.61->langchain_openai) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.61->langchain_openai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.61->langchain_openai) (0.23.0)
# Requirement already satisfied: sniffio in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain_openai) (1.3.1)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain_openai) (1.9.0)
# Requirement already satisfied: tqdm>4 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain_openai) (4.67.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain_openai) (0.10.0)
# Requirement already satisfied: wcwidth in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: pydantic-core==2.33.2 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from pydantic>=2.7.4->langgraph) (2.33.2)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.4.1)
# Requirement already satisfied: six>=1.5 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.17.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.61->langchain_openai) (2.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.61->langchain_openai) (3.4.2)
# Requirement already satisfied: regex>=2022.1.18 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from tiktoken<1,>=0.7->langchain_openai) (2024.11.6)
# Requirement already satisfied: asttokens>=2.1.0 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the 'd:\MIOTI\Deep Learning\TFM\Entorno\tfm\.venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# %%capture

# # MCP LangChain
#%pip install langchain-mcp-adapters python-dotenv
# Out:
# Collecting langchain-mcp-adaptersNote: you may need to restart the kernel to use updated packages.
#
#   Downloading langchain_mcp_adapters-0.1.1-py3-none-any.whl (12 kB)
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Collecting mcp>=1.7
#   Downloading mcp-1.9.1-py3-none-any.whl (130 kB)
# Requirement already satisfied: langchain-core<0.4,>=0.3.36 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langchain-mcp-adapters) (0.3.61)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (9.1.2)
# Requirement already satisfied: langsmith<0.4,>=0.1.126 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (0.3.42)
# Requirement already satisfied: pydantic>=2.7.4 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (2.11.5)
# Requirement already satisfied: PyYAML>=5.3 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.7 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (4.13.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (24.2)
# Requirement already satisfied: jsonpointer>=1.9 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (3.10.18)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (0.23.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (1.0.0)
# Requirement already satisfied: requests<3,>=2 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (2.32.3)
# Requirement already satisfied: idna in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (3.10)
# Requirement already satisfied: certifi in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (1.0.9)
# Requirement already satisfied: anyio in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (4.9.0)
# Requirement already satisfied: h11>=0.16 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (0.16.0)
# Collecting python-multipart>=0.0.9
#   Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Collecting starlette>=0.27
#   Downloading starlette-0.46.2-py3-none-any.whl (72 kB)
# Collecting uvicorn>=0.23.1
#   Downloading uvicorn-0.34.2-py3-none-any.whl (62 kB)
# Collecting pydantic-settings>=2.5.2
#   Downloading pydantic_settings-2.9.1-py3-none-any.whl (44 kB)
# Collecting httpx-sse>=0.4
#   Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Collecting sse-starlette>=1.6.1
#   Downloading sse_starlette-2.3.5-py3-none-any.whl (10 kB)
# Requirement already satisfied: sniffio>=1.1 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (1.3.0)
# Requirement already satisfied: pydantic-core==2.33.2 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from pydantic>=2.7.4->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from pydantic>=2.7.4->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (0.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from pydantic>=2.7.4->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (0.7.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (2.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (3.4.2)
# Collecting click>=7.0
#   Downloading click-8.2.1-py3-none-any.whl (102 kB)
# Requirement already satisfied: colorama in d:\mioti\deep learning\tfm\entorno\tfm\.venv\lib\site-packages (from click>=7.0->uvicorn>=0.23.1->mcp>=1.7->langchain-mcp-adapters) (0.4.6)
# Installing collected packages: starlette, python-dotenv, click, uvicorn, sse-starlette, python-multipart, pydantic-settings, httpx-sse, mcp, langchain-mcp-adapters
# Successfully installed click-8.2.1 httpx-sse-0.4.0 langchain-mcp-adapters-0.1.1 mcp-1.9.1 pydantic-settings-2.9.1 python-dotenv-1.1.0 python-multipart-0.0.20 sse-starlette-2.3.5 starlette-0.46.2 uvicorn-0.34.2
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the 'd:\MIOTI\Deep Learning\TFM\Entorno\tfm\.venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# Imports

import os
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

# %%
# APIs

# OpenAI
load_dotenv()

# Ahora la clave está en la variable de entorno
api_key = os.getenv("OPENAI_API_KEY")
if not api_key:
    raise ValueError("No se encontró OPENAI_API_KEY en las variables de entorno")


# Langsmith
#os.environ["LANGSMITH_API_KEY"] = "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"
#os.environ["LANGSMITH_TRACING_V2"] = "true"

# %%
# Modelo

model = ChatOpenAI(model="gpt-4.1-nano",)
# model = ChatOpenAI(model="gpt-4.1-mini")

# %%
# Evitar error de asyncio en Windows

import asyncio
asyncio.set_event_loop_policy(asyncio.WindowsProactorEventLoopPolicy())

# %%
# Config

import uuid

config = {"configurable": {"thread_id": str(uuid.uuid4()), "user_id": "1"}}

# %%
# Streaming para LangGraph

def print_stream(stream):
    for ns, update in stream:
        print(f"Namespace '{ns}'")
        for node, node_updates in update.items():
            if node_updates is None:
                continue

            if isinstance(node_updates, (dict, tuple)):
                node_updates_list = [node_updates]
            elif isinstance(node_updates, list):
                node_updates_list = node_updates
            else:
                raise ValueError(node_updates)

            for node_updates in node_updates_list:
                print(f"Update from node '{node}'")
                if isinstance(node_updates, tuple):
                    print(node_updates)
                    continue
                messages_key = next(
                    (k for k in node_updates.keys() if "messages" in k), None
                )
                if messages_key is not None:
                    node_updates[messages_key][-1].pretty_print()
                else:
                    print(node_updates)

        print("\n\n")

    print("\n===\n")

# %% [markdown]
# # Supervisor

# %%
from langgraph_supervisor import create_supervisor
from pydantic import BaseModel, Field
from langchain_core.runnables import RunnableConfig
from langgraph.checkpoint.memory import MemorySaver
from langgraph.prebuilt import create_react_agent
from langgraph_swarm import create_handoff_tool, create_swarm
from langchain_core.tools import tool
import json
from langchain_openai import ChatOpenAI
from pathlib import Path


def make_prompt(base_prompt: str):
    def _prompt(state: dict, config: RunnableConfig) -> list:
        user_id = config["configurable"].get("user_id")
        return [
            {
                "role": "system",
                "content": (
                    f"{base_prompt}\n"
                )
            },
            *state["messages"],
        ]
    return _prompt

import os
import json
import uuid

@tool
def get_document(document: str) -> str:
    """Devuelve el Markdown completo de la factura"""
    return document



s_date_bill = create_react_agent(
    model,
    tools=[get_document],
    prompt=make_prompt(
        "### Role\n"
        "You are an expert in extracting invoice issue dates.\n\n"
        "### Objective\n"
        "Identify and extract the issue date from the provided invoice document.\n\n"
        "### Instructions\n"
        "- Focus solely on the invoice issue date.\n"
        "- Format the date as 'DD-MM-YYYY'.\n"
        "- Ignore any other dates present in the document.\n\n"
        "### Output Format\n"
        "{\n"
        "  \"Date\": \"DD-MM-YYYY\"\n"
        "}"
    ),
    name="date_bill",
)


s_number_bill = create_react_agent(
    model,
    tools=[get_document],
    prompt=make_prompt(
        "### Role\n"
        "You are an expert in identifying invoice numbers.\n\n"
        "### Objective\n"
        "Locate and extract the invoice number from the provided document.\n\n"
        "### Instructions\n"
        "- Look for identifiers labeled as 'Invoice No.', 'Invoice Number', or similar.\n"
        "- Exclude any numbers related to clients or customers.\n\n"
        "### Output Format\n"
        "{\n"
        "  \"InvoiceNumber\": \"<InvoiceNumber>\"\n"
        "}"
    ),
    name="number_bill",
)


s_vehicle_plate_bill = create_react_agent(
    model,
    tools=[get_document],
    prompt=make_prompt(
        "### Role\n"
        "You are an expert in recognizing European vehicle license plates.\n\n"
        "### Objective\n"
        "Identify and extract any vehicle license plates present in the document.\n\n"
        "### Instructions\n"
        "- Recognize the following formats:\n"
        "  - 1234 ABC\n"
        "  - 1234-ABC\n"
        "  - 1234ABC\n"
        "  - AB 1234 C\n"
        "  - AB1234C\n"
        "  - AB 1234 CU\n"
        "  - AB1234CU\n"
        "- If a license plate is found, return it; otherwise, return null.\n\n"
        "### Output Format\n"
        "{\n"
        "  \"VehiclePlate\": \"<VehiclePlate>\" // or null\n"
        "}"
    ),
    name="vehicle_plate_bill",
)


s_total_amount_bill = create_react_agent(
    model,
    tools=[get_document],
    prompt=make_prompt(
        "### Role\n"
        "You are an expert in extracting total amounts from invoices.\n\n"
        "### Objective\n"
        "Identify and extract the total amount due from the invoice.\n\n"
        "### Instructions\n"
        "- Focus on the final total amount payable.\n"
        "- Format the amount with a comma as the decimal separator and include the '€' symbol.\n\n"
        "### Output Format\n"
        "{\n"
        "  \"TotalAmount\": \"<Amount> €\"\n"
        "}"
    ),
    name="total_amount_bill",
)


s_company_bill = create_react_agent(
    model,
    tools=[get_document],
    prompt=make_prompt(
        "### Role\n"
        "You are an expert in identifying issuing companies on invoices under Spanish law.\n\n"
        "### Objective\n"
        "Extract the name and NIF of the company that issued the invoice.\n\n"
        "### Instructions\n"
        "- Identify the company that provided, leased, or rented the vehicle.\n"
        "- Exclude the following:\n"
        "  - Company Name: 'DEABRU KALEA FILMEAK, S.L.U.'\n"
        "  - NIF: 'B75587808'\n"
        "- If the issuing company is not found, return null.\n\n"
        "### Output Format\n"
        "{\n"
        "  \"CompanyName\": \"<CompanyName>\",\n"
        "  \"NIF\": \"<NIF>\"\n"
        "}"
    ),
    name="company_bill",
)


s_report_bill = create_react_agent(
    model,
    prompt=make_prompt(
        "### Role\n"
        "You are responsible for compiling invoice data into a final report.\n\n"
        "### Objective\n"
        "Use the provided values to generate a final JSON report.\n\n"
        "### Instructions\n"
        "- Utilize the 'generate_final_json' tool with the following fields:\n"
        "  - Date\n"
        "  - InvoiceNumber\n"
        "  - VehiclePlate\n"
        "  - TotalAmount\n"
        "  - CompanyName\n"
        "  - NIF\n"
        "- Call the tool exactly once.\n"
        "- Return only the file path provided by the tool.\n\n"
        "### Output Format\n"
        "<file_path>"
    ),
    name="report_bill",
)


s_validate_report_bill = create_react_agent(
    model,
    # tools=[read_json_file, update_json_file],
    prompt=make_prompt(
        "### Role\n"
        "You are responsible for validating and correcting invoice JSON reports.\n\n"
        "### Objective\n"
        "Ensure the JSON file at the provided path adheres to the required format and content standards.\n\n"
        "### Instructions\n"
        "1. Read the JSON content using 'read_json_file'.\n"
        "2. Validate and correct the following:\n"
        "   - 'Date' should be in 'DD-MM-YYYY' format.\n"
        "   - Keys must be exactly: Date, InvoiceNumber, VehiclePlate, TotalAmount, CompanyName, NIF.\n"
        "   - 'TotalAmount' must use a comma as the decimal separator and include the '€' symbol.\n"
        "3. If corrections are made, update the file using 'update_json_file'.\n"
        "4. Return the final JSON content without additional text or tool calls.\n\n"
        "### Output Format\n"
        "{\n"
        "  \"Date\": \"DD-MM-YYYY\",\n"
        "  \"InvoiceNumber\": \"<InvoiceNumber>\",\n"
        "  \"VehiclePlate\": \"<VehiclePlate>\",\n"
        "  \"TotalAmount\": \"<Amount> €\",\n"
        "  \"CompanyName\": \"<CompanyName>\",\n"
        "  \"NIF\": \"<NIF>\"\n"
        "}"
    ),
    name="validate_report_bill",
)


supervisor = create_supervisor(
    [s_date_bill, s_number_bill, s_vehicle_plate_bill, s_total_amount_bill, s_company_bill, s_report_bill, s_validate_report_bill],
    model=model,
    prompt=make_prompt(
        """
        ### Role
        You are a supervisor coordinating the work of several specialized agents to extract and validate invoice information.

        ### Objective
        Ensure the accurate extraction of the following fields from an invoice:
        - Date
        - InvoiceNumber
        - VehiclePlate
        - TotalAmount
        - CompanyName
        - NIF

        ### Instructions
        1. **Planning**: Before initiating any agent calls, plan the sequence of actions required to extract all necessary information.
        2. **Agent Coordination**:
            - Assign each agent to its specific task:
                - `date_bill`: Extract the invoice date.
                - `number_bill`: Extract the invoice number.
                - `vehicle_plate_bill`: Extract the vehicle plate number.
                - `total_amount_bill`: Extract the total amount.
                - `company_bill`: Extract the company name and NIF.
            - Do not ask agents to perform tasks outside their designated responsibilities.
        3. **Data Saving**: Instruct agents to save their results using their respective tools, even if the result is `null`.
        4. **Report Generation**:
            - Once all individual data points are collected and saved, call the `report_bill` agent to compile the data into a single JSON file.
        5. **Validation**:
            - After the report is generated, call the `validate_report_bill` agent with the path to the JSON file to ensure all data is correctly formatted and complete.
        6. **Final Output**:
            - Present only the validated JSON content to the user, without any additional commentary or text.

        ### Agent Descriptions
        - `date_bill`: Extracts the invoice date.
        - `number_bill`: Extracts the invoice number.
        - `vehicle_plate_bill`: Extracts the vehicle plate number.
        - `total_amount_bill`: Extracts the total amount.
        - `company_bill`: Extracts the company name and NIF.
        - `report_bill`: Compiles all extracted data into a single JSON file.
        - `validate_report_bill`: Validates and corrects the compiled JSON file.

        ### Output Format
        The final JSON should have the following structure:
        {
            "Date": "DD-MM-YYYY",
            "InvoiceNumber": "InvoiceNumber",
            "VehiclePlate": "VehiclePlate",
            "TotalAmount": "TotalAmount",
            "CompanyName": "CompanyName",
            "NIF": "NIF"
        }

        ### Final Notes
        - Do not terminate your process until all fields are accurately extracted, compiled, and validated.
        - Ensure all agents perform only their designated tasks.
        - Maintain a clear and structured approach throughout the process.
        """
    )
)


s_app = supervisor.compile()

# %%
config = {
    "configurable": {
        "user_id": "mesmo",
        # "document": md_content,
    }
}

print_stream(
    s_app.stream(
        {
            "messages": [
                {"role": "user", "content": "Cuál es el número, fecha, matrícula, importe y empresa (y NIF) de la factura?"} # ← pregunta inicial
            ]
        },
        config,          # ← tu diccionario con configurable
        subgraphs=True,  # ← si quieres ver los saltos internos
    )
)
